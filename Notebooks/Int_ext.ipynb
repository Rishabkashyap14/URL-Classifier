# %%
import pandas as pd
import numpy as np
import collections
import requests
import urllib.parse
import colorama
import time
import bs4

from collections import defaultdict
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup

# %%
'''
Simple program to gather all the internal and external links. NOT to be confused with inlinks and outlinks.
Internal links are those links that point to another website within the same domain
External links are those links that point to another website that does NOT share the same domain
Reference link: https://www.thepythoncode.com/article/extract-all-website-links-python
'''
#Colorama is a simple tool used to display different colors on the terminal 
colorama.init()
GREEN = colorama.Fore.GREEN
GRAY = colorama.Fore.LIGHTBLACK_EX
RESET = colorama.Fore.RESET
YELLOW = colorama.Fore.YELLOW

# max_urls define the maximum number of urls it must crawl to obtain the rest of the urls
# The internal and external URLs are put into sets to prevent redundancy
max_urls = 10
final_internal = list ()
final_external = list ()

#Basic methos to find whether a given URL is valid or not, just like our method
def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

# Below function gets all the links, and as a trial we consider only the a tags for the time being.     
def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    # all URLs of `url`
    urls = set()
    # domain name of the URL without the protocol
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            # href empty tag
            continue
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        # remove URL GET parameters, URL fragments, etc.
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_valid(href):
            # not a valid URL
            continue
        if href in internal_urls:
            # already in the set
            continue
        if domain_name not in href:
            # external link
            if href not in external_urls:
                #print(f"{GRAY}[!] External link: {href}{RESET}")
                external_urls.add(href)
            continue
        #print(f"{GREEN}[*] Internal link: {href}{RESET}")
        urls.add(href)
        internal_urls.add(href)
    return urls

total_urls_visited = 0

def crawl(url, max_urls):
    """
    Crawls a web page and extracts all links.
    You'll find all links in `external_urls` and `internal_urls` global set variables.
    params:
        max_urls (int): number of max urls to crawl, default is 10.
    """
    global total_urls_visited
    total_urls_visited += 1
    #print(f"{YELLOW}[*] Crawling: {url}{RESET}")
    links = get_all_website_links(url)
    for link in links:
        if total_urls_visited > max_urls:
            break
        crawl(link, max_urls=max_urls)

Sample1 = pd.read_csv('whoisLegi.csv')
#Sample1 = pd.read_csv('/content/drive/MyDrive/whoisLegi.csv')

start = time.time()
count = 1
print("Program starting, for any URLs taking more than 10s press ctrl+c")
for i in Sample1.URL:
    internal_urls = set ()
    external_urls = set ()
    start_1 = time.time()
    print("URL:",count)
    count +=1
    try:
        crawl(i, max_urls)
        print("[+] Total Internal links:", len(internal_urls))
        final_internal.append(len(internal_urls))
        print("[+] Total External links:", len(external_urls))
        final_external.append(len(external_urls))
        print("[+] Total URLs:", len(external_urls) + len(internal_urls))
        print("[+] Total crawled URLs:", max_urls)
    except:
        print("Not a valid URL\n")
        final_internal.append(0)
        final_external.append(0)
        continue
    end_1 = time.time()
    print("Intermediate execution",count,"in",end_1-start_1,"seconds")
end = time.time()
print("Finished execution in:",end-start,"seconds")
# Out:
# Program starting, for any URLs taking more than 10s press ctrl+c
# URL: 1
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [+] Total Internal links: 123
# [+] Total External links: 108
# [+] Total URLs: 231
# [+] Total crawled URLs: 10
# Intermediate execution 2 in 27.820612907409668 seconds
# URL: 2
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 3 in 1.2497775554656982 seconds
# URL: 3
# Not a valid URL
#
# URL: 4
# [+] Total Internal links: 35
# [+] Total External links: 2
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 5 in 1.6790533065795898 seconds
# URL: 5
# [+] Total Internal links: 0
# [+] Total External links: 2
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 6 in 0.8735733032226562 seconds
# URL: 6
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 7 in 0.23751282691955566 seconds
# URL: 7
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 8 in 1.452807903289795 seconds
# URL: 8
# [+] Total Internal links: 12
# [+] Total External links: 26
# [+] Total URLs: 38
# [+] Total crawled URLs: 10
# Intermediate execution 9 in 2.3158888816833496 seconds
# URL: 9
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 10 in 1.9599971771240234 seconds
# URL: 10
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 11 in 1.1431269645690918 seconds
# URL: 11
# [+] Total Internal links: 116
# [+] Total External links: 39
# [+] Total URLs: 155
# [+] Total crawled URLs: 10
# Intermediate execution 12 in 17.960607528686523 seconds
# URL: 12
# [+] Total Internal links: 8
# [+] Total External links: 3
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 13 in 1.3103516101837158 seconds
# URL: 13
# [+] Total Internal links: 23
# [+] Total External links: 18
# [+] Total URLs: 41
# [+] Total crawled URLs: 10
# Intermediate execution 14 in 0.7381000518798828 seconds
# URL: 14
# [+] Total Internal links: 1
# [+] Total External links: 1
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 15 in 1.7323226928710938 seconds
# URL: 15
# [+] Total Internal links: 4
# [+] Total External links: 34
# [+] Total URLs: 38
# [+] Total crawled URLs: 10
# Intermediate execution 16 in 4.913557291030884 seconds
# URL: 16
# [+] Total Internal links: 2
# [+] Total External links: 2
# [+] Total URLs: 4
# [+] Total crawled URLs: 10
# Intermediate execution 17 in 1.7783730030059814 seconds
# URL: 17
# [+] Total Internal links: 1
# [+] Total External links: 129
# [+] Total URLs: 130
# [+] Total crawled URLs: 10
# Intermediate execution 18 in 4.1955811977386475 seconds
# URL: 18
# [+] Total Internal links: 83
# [+] Total External links: 2
# [+] Total URLs: 85
# [+] Total crawled URLs: 10
# Intermediate execution 19 in 1.5141136646270752 seconds
# URL: 19
# [+] Total Internal links: 2
# [+] Total External links: 1
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 20 in 2.8809938430786133 seconds
# URL: 20
# [+] Total Internal links: 3
# [+] Total External links: 5
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 21 in 2.065422534942627 seconds
# URL: 21
# [+] Total Internal links: 17
# [+] Total External links: 10
# [+] Total URLs: 27
# [+] Total crawled URLs: 10
# Intermediate execution 22 in 1.9115760326385498 seconds
# URL: 22
# [+] Total Internal links: 10
# [+] Total External links: 9
# [+] Total URLs: 19
# [+] Total crawled URLs: 10
# Intermediate execution 23 in 0.6760578155517578 seconds
# URL: 23
# Not a valid URL
#
# URL: 24
# [+] Total Internal links: 163
# [+] Total External links: 26
# [+] Total URLs: 189
# [+] Total crawled URLs: 10
# Intermediate execution 25 in 5.510007858276367 seconds
# URL: 25
# [+] Total Internal links: 5
# [+] Total External links: 6
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 26 in 2.7965197563171387 seconds
# URL: 26
# [+] Total Internal links: 17
# [+] Total External links: 34
# [+] Total URLs: 51
# [+] Total crawled URLs: 10
# Intermediate execution 27 in 1.3437411785125732 seconds
# URL: 27
# [+] Total Internal links: 5
# [+] Total External links: 1
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 28 in 2.0004310607910156 seconds
# URL: 28
# [+] Total Internal links: 42
# [+] Total External links: 8
# [+] Total URLs: 50
# [+] Total crawled URLs: 10
# Intermediate execution 29 in 4.04088568687439 seconds
# URL: 29
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 30 in 1.5669522285461426 seconds
# URL: 30
# [+] Total Internal links: 6
# [+] Total External links: 5
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 31 in 0.6579129695892334 seconds
# URL: 31
# [+] Total Internal links: 0
# [+] Total External links: 7
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 32 in 3.613377809524536 seconds
# URL: 32
# [+] Total Internal links: 38
# [+] Total External links: 5
# [+] Total URLs: 43
# [+] Total crawled URLs: 10
# Intermediate execution 33 in 2.793959140777588 seconds
# URL: 33
# [+] Total Internal links: 11
# [+] Total External links: 1
# [+] Total URLs: 12
# [+] Total crawled URLs: 10
# Intermediate execution 34 in 0.8256356716156006 seconds
# URL: 34
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 35 in 1.2662427425384521 seconds
# URL: 35
# Not a valid URL
#
# URL: 36
# [+] Total Internal links: 9
# [+] Total External links: 4
# [+] Total URLs: 13
# [+] Total crawled URLs: 10
# Intermediate execution 37 in 3.526381731033325 seconds
# URL: 37
# [+] Total Internal links: 7
# [+] Total External links: 3
# [+] Total URLs: 10
# [+] Total crawled URLs: 10
# Intermediate execution 38 in 1.9483370780944824 seconds
# URL: 38
# [+] Total Internal links: 13
# [+] Total External links: 1
# [+] Total URLs: 14
# [+] Total crawled URLs: 10
# Intermediate execution 39 in 2.546691656112671 seconds
# URL: 39
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 40 in 1.4178717136383057 seconds
# URL: 40
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 41 in 3.6759560108184814 seconds
# URL: 41
# [+] Total Internal links: 12
# [+] Total External links: 51
# [+] Total URLs: 63
# [+] Total crawled URLs: 10
# Intermediate execution 42 in 3.399340867996216 seconds
# URL: 42
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 43 in 0.3581211566925049 seconds
# URL: 43
# [+] Total Internal links: 20
# [+] Total External links: 4
# [+] Total URLs: 24
# [+] Total crawled URLs: 10
# Intermediate execution 44 in 1.9615120887756348 seconds
# URL: 44
# [+] Total Internal links: 1
# [+] Total External links: 83
# [+] Total URLs: 84
# [+] Total crawled URLs: 10
# Intermediate execution 45 in 5.057430028915405 seconds
# URL: 45
# Not a valid URL
#
# URL: 46
# [+] Total Internal links: 27
# [+] Total External links: 5
# [+] Total URLs: 32
# [+] Total crawled URLs: 10
# Intermediate execution 47 in 2.343973398208618 seconds
# URL: 47
# [+] Total Internal links: 39
# [+] Total External links: 7
# [+] Total URLs: 46
# [+] Total crawled URLs: 10
# Intermediate execution 48 in 1.0591630935668945 seconds
# URL: 48
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 49 in 2.1716065406799316 seconds
# URL: 49
# [+] Total Internal links: 71
# [+] Total External links: 4
# [+] Total URLs: 75
# [+] Total crawled URLs: 10
# Intermediate execution 50 in 3.1013879776000977 seconds
# URL: 50
# [+] Total Internal links: 140
# [+] Total External links: 79
# [+] Total URLs: 219
# [+] Total crawled URLs: 10
# Intermediate execution 51 in 0.5401995182037354 seconds
# URL: 51
# Not a valid URL
#
# URL: 52
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 53 in 0.5476219654083252 seconds
# URL: 53
# [+] Total Internal links: 110
# [+] Total External links: 19
# [+] Total URLs: 129
# [+] Total crawled URLs: 10
# Intermediate execution 54 in 2.3161535263061523 seconds
# URL: 54
# Not a valid URL
#
# URL: 55
# [+] Total Internal links: 205
# [+] Total External links: 25
# [+] Total URLs: 230
# [+] Total crawled URLs: 10
# Intermediate execution 56 in 2.36954665184021 seconds
# URL: 56
# [+] Total Internal links: 14
# [+] Total External links: 4
# [+] Total URLs: 18
# [+] Total crawled URLs: 10
# Intermediate execution 57 in 1.778409481048584 seconds
# URL: 57
# [+] Total Internal links: 2
# [+] Total External links: 28
# [+] Total URLs: 30
# [+] Total crawled URLs: 10
# Intermediate execution 58 in 1.4064595699310303 seconds
# URL: 58
# [+] Total Internal links: 0
# [+] Total External links: 3
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 59 in 1.4393393993377686 seconds
# URL: 59
# [+] Total Internal links: 66
# [+] Total External links: 2
# [+] Total URLs: 68
# [+] Total crawled URLs: 10
# Intermediate execution 60 in 1.475532054901123 seconds
# URL: 60
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 61 in 0.8301980495452881 seconds
# URL: 61
# [+] Total Internal links: 17
# [+] Total External links: 30
# [+] Total URLs: 47
# [+] Total crawled URLs: 10
# Intermediate execution 62 in 2.426304817199707 seconds
# URL: 62
# [+] Total Internal links: 0
# [+] Total External links: 29
# [+] Total URLs: 29
# [+] Total crawled URLs: 10
# Intermediate execution 63 in 4.1262171268463135 seconds
# URL: 63
# [+] Total Internal links: 10
# [+] Total External links: 10
# [+] Total URLs: 20
# [+] Total crawled URLs: 10
# Intermediate execution 64 in 3.4016871452331543 seconds
# URL: 64
# [+] Total Internal links: 1
# [+] Total External links: 8
# [+] Total URLs: 9
# [+] Total crawled URLs: 10
# Intermediate execution 65 in 2.9868197441101074 seconds
# URL: 65
# [+] Total Internal links: 77
# [+] Total External links: 2
# [+] Total URLs: 79
# [+] Total crawled URLs: 10
# Intermediate execution 66 in 2.4655096530914307 seconds
# URL: 66
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 67 in 0.6081602573394775 seconds
# URL: 67
# [+] Total Internal links: 143
# [+] Total External links: 82
# [+] Total URLs: 225
# [+] Total crawled URLs: 10
# Intermediate execution 68 in 2.6929872035980225 seconds
# URL: 68
# [+] Total Internal links: 39
# [+] Total External links: 4
# [+] Total URLs: 43
# [+] Total crawled URLs: 10
# Intermediate execution 69 in 1.3544881343841553 seconds
# URL: 69
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 70 in 1.78422212600708 seconds
# URL: 70
# [+] Total Internal links: 18
# [+] Total External links: 213
# [+] Total URLs: 231
# [+] Total crawled URLs: 10
# Intermediate execution 71 in 2.310793161392212 seconds
# URL: 71
# [+] Total Internal links: 36
# [+] Total External links: 3
# [+] Total URLs: 39
# [+] Total crawled URLs: 10
# Intermediate execution 72 in 1.5136241912841797 seconds
# URL: 72
# [+] Total Internal links: 27
# [+] Total External links: 5
# [+] Total URLs: 32
# [+] Total crawled URLs: 10
# Intermediate execution 73 in 1.189317226409912 seconds
# URL: 73
# [+] Total Internal links: 83
# [+] Total External links: 5
# [+] Total URLs: 88
# [+] Total crawled URLs: 10
# Intermediate execution 74 in 1.4710252285003662 seconds
# URL: 74
# Not a valid URL
#
# URL: 75
# [+] Total Internal links: 15
# [+] Total External links: 34
# [+] Total URLs: 49
# [+] Total crawled URLs: 10
# Intermediate execution 76 in 0.9514131546020508 seconds
# URL: 76
# Not a valid URL
#
# URL: 77
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 78 in 1.5493900775909424 seconds
# URL: 78
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 79 in 1.3242743015289307 seconds
# URL: 79
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 80 in 2.6029045581817627 seconds
# URL: 80
# [+] Total Internal links: 9
# [+] Total External links: 3
# [+] Total URLs: 12
# [+] Total crawled URLs: 10
# Intermediate execution 81 in 0.9926066398620605 seconds
# URL: 81
# [+] Total Internal links: 22
# [+] Total External links: 2
# [+] Total URLs: 24
# [+] Total crawled URLs: 10
# Intermediate execution 82 in 1.3999414443969727 seconds
# URL: 82
# [+] Total Internal links: 55
# [+] Total External links: 34
# [+] Total URLs: 89
# [+] Total crawled URLs: 10
# Intermediate execution 83 in 0.3721761703491211 seconds
# URL: 83
# Not a valid URL
#
# URL: 84
# [+] Total Internal links: 1
# [+] Total External links: 2
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 85 in 1.0732271671295166 seconds
# URL: 85
# [+] Total Internal links: 52
# [+] Total External links: 10
# [+] Total URLs: 62
# [+] Total crawled URLs: 10
# Intermediate execution 86 in 1.7788183689117432 seconds
# URL: 86
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 87 in 1.7902662754058838 seconds
# URL: 87
# [+] Total Internal links: 48
# [+] Total External links: 2
# [+] Total URLs: 50
# [+] Total crawled URLs: 10
# Intermediate execution 88 in 1.508683681488037 seconds
# URL: 88
# [+] Total Internal links: 20
# [+] Total External links: 2
# [+] Total URLs: 22
# [+] Total crawled URLs: 10
# Intermediate execution 89 in 1.968364953994751 seconds
# URL: 89
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 90 in 0.2286832332611084 seconds
# URL: 90
# [+] Total Internal links: 4
# [+] Total External links: 2
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 91 in 1.181095838546753 seconds
# URL: 91
# [+] Total Internal links: 54
# [+] Total External links: 8
# [+] Total URLs: 62
# [+] Total crawled URLs: 10
# Intermediate execution 92 in 0.639617919921875 seconds
# URL: 92
# [+] Total Internal links: 2
# [+] Total External links: 0
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 93 in 4.649183511734009 seconds
# URL: 93
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 94 in 1.2797424793243408 seconds
# URL: 94
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 95 in 0.9071547985076904 seconds
# URL: 95
# Not a valid URL
#
# URL: 96
# [+] Total Internal links: 2
# [+] Total External links: 11
# [+] Total URLs: 13
# [+] Total crawled URLs: 10
# Intermediate execution 97 in 2.0973007678985596 seconds
# URL: 97
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 98 in 1.2383577823638916 seconds
# URL: 98
# [+] Total Internal links: 54
# [+] Total External links: 2
# [+] Total URLs: 56
# [+] Total crawled URLs: 10
# Intermediate execution 99 in 3.6054577827453613 seconds
# URL: 99
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 100 in 0.5501658916473389 seconds
# URL: 100
# [+] Total Internal links: 2
# [+] Total External links: 87
# [+] Total URLs: 89
# [+] Total crawled URLs: 10
# Intermediate execution 101 in 3.394223928451538 seconds
# URL: 101
# [+] Total Internal links: 25
# [+] Total External links: 2
# [+] Total URLs: 27
# [+] Total crawled URLs: 10
# Intermediate execution 102 in 1.5158202648162842 seconds
# URL: 102
# [+] Total Internal links: 0
# [+] Total External links: 2
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 103 in 0.25513339042663574 seconds
# URL: 103
# [+] Total Internal links: 2
# [+] Total External links: 0
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 104 in 1.3074891567230225 seconds
# URL: 104
# Not a valid URL
#
# URL: 105
# [+] Total Internal links: 51
# [+] Total External links: 2
# [+] Total URLs: 53
# [+] Total crawled URLs: 10
# Intermediate execution 106 in 1.4354820251464844 seconds
# URL: 106
# [+] Total Internal links: 2
# [+] Total External links: 33
# [+] Total URLs: 35
# [+] Total crawled URLs: 10
# Intermediate execution 107 in 3.007161855697632 seconds
# URL: 107
# [+] Total Internal links: 0
# [+] Total External links: 11
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 108 in 1.2281694412231445 seconds
# URL: 108
# [+] Total Internal links: 6
# [+] Total External links: 3
# [+] Total URLs: 9
# [+] Total crawled URLs: 10
# Intermediate execution 109 in 2.6425344944000244 seconds
# URL: 109
# [+] Total Internal links: 42
# [+] Total External links: 5
# [+] Total URLs: 47
# [+] Total crawled URLs: 10
# Intermediate execution 110 in 4.3984575271606445 seconds
# URL: 110
# [+] Total Internal links: 106
# [+] Total External links: 8
# [+] Total URLs: 114
# [+] Total crawled URLs: 10
# Intermediate execution 111 in 1.70219087600708 seconds
# URL: 111
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 112 in 0.6853108406066895 seconds
# URL: 112
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 113 in 1.5169949531555176 seconds
# URL: 113
# [+] Total Internal links: 12
# [+] Total External links: 2
# [+] Total URLs: 14
# [+] Total crawled URLs: 10
# Intermediate execution 114 in 6.936755180358887 seconds
# URL: 114
# [+] Total Internal links: 15
# [+] Total External links: 1
# [+] Total URLs: 16
# [+] Total crawled URLs: 10
# Intermediate execution 115 in 1.0426640510559082 seconds
# URL: 115
# [+] Total Internal links: 1
# [+] Total External links: 5
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 116 in 0.991689920425415 seconds
# URL: 116
# Not a valid URL
#
# URL: 117
# [+] Total Internal links: 24
# [+] Total External links: 107
# [+] Total URLs: 131
# [+] Total crawled URLs: 10
# Intermediate execution 118 in 2.5362095832824707 seconds
# URL: 118
# [+] Total Internal links: 1
# [+] Total External links: 77
# [+] Total URLs: 78
# [+] Total crawled URLs: 10
# Intermediate execution 119 in 3.7943334579467773 seconds
# URL: 119
# Not a valid URL
#
# URL: 120
# [+] Total Internal links: 2
# [+] Total External links: 3
# [+] Total URLs: 5
# [+] Total crawled URLs: 10
# Intermediate execution 121 in 1.1358048915863037 seconds
# URL: 121
# [+] Total Internal links: 1
# [+] Total External links: 1
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 122 in 1.8839480876922607 seconds
# URL: 122
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 123 in 0.4839000701904297 seconds
# URL: 123
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 124 in 1.009030818939209 seconds
# URL: 124
# [+] Total Internal links: 118
# [+] Total External links: 20
# [+] Total URLs: 138
# [+] Total crawled URLs: 10
# Intermediate execution 125 in 1.986250400543213 seconds
# URL: 125
# Not a valid URL
#
# URL: 126
# [+] Total Internal links: 19
# [+] Total External links: 0
# [+] Total URLs: 19
# [+] Total crawled URLs: 10
# Intermediate execution 127 in 0.7101020812988281 seconds
# URL: 127
# [+] Total Internal links: 52
# [+] Total External links: 3
# [+] Total URLs: 55
# [+] Total crawled URLs: 10
# Intermediate execution 128 in 1.8917148113250732 seconds
# URL: 128
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 129 in 2.842146635055542 seconds
# URL: 129
# [+] Total Internal links: 106
# [+] Total External links: 19
# [+] Total URLs: 125
# [+] Total crawled URLs: 10
# Intermediate execution 130 in 0.8943586349487305 seconds
# URL: 130
# [+] Total Internal links: 73
# [+] Total External links: 663
# [+] Total URLs: 736
# [+] Total crawled URLs: 10
# Intermediate execution 131 in 3.9649147987365723 seconds
# URL: 131
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 132 in 1.5572748184204102 seconds
# URL: 132
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 133 in 2.729952096939087 seconds
# URL: 133
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 134 in 0.9920101165771484 seconds
# URL: 134
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 135 in 2.3024303913116455 seconds
# URL: 135
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 136 in 1.9843859672546387 seconds
# URL: 136
# [+] Total Internal links: 16
# [+] Total External links: 0
# [+] Total URLs: 16
# [+] Total crawled URLs: 10
# Intermediate execution 137 in 6.016525745391846 seconds
# URL: 137
# [+] Total Internal links: 74
# [+] Total External links: 14
# [+] Total URLs: 88
# [+] Total crawled URLs: 10
# Intermediate execution 138 in 2.3603177070617676 seconds
# URL: 138
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 139 in 1.4511215686798096 seconds
# URL: 139
# [+] Total Internal links: 11
# [+] Total External links: 2
# [+] Total URLs: 13
# [+] Total crawled URLs: 10
# Intermediate execution 140 in 0.8037815093994141 seconds
# URL: 140
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 141 in 0.4753584861755371 seconds
# URL: 141
# [+] Total Internal links: 0
# [+] Total External links: 4
# [+] Total URLs: 4
# [+] Total crawled URLs: 10
# Intermediate execution 142 in 1.8726749420166016 seconds
# URL: 142
# [+] Total Internal links: 24
# [+] Total External links: 58
# [+] Total URLs: 82
# [+] Total crawled URLs: 10
# Intermediate execution 143 in 1.606107234954834 seconds
# URL: 143
# [+] Total Internal links: 98
# [+] Total External links: 10
# [+] Total URLs: 108
# [+] Total crawled URLs: 10
# Intermediate execution 144 in 3.6574864387512207 seconds
# URL: 144
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 145 in 4.056900501251221 seconds
# URL: 145
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 146 in 0.29072093963623047 seconds
# URL: 146
# [+] Total Internal links: 2
# [+] Total External links: 29
# [+] Total URLs: 31
# [+] Total crawled URLs: 10
# Intermediate execution 147 in 2.0743935108184814 seconds
# URL: 147
# [+] Total Internal links: 6
# [+] Total External links: 2
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 148 in 0.9090991020202637 seconds
# URL: 148
# [+] Total Internal links: 23
# [+] Total External links: 3
# [+] Total URLs: 26
# [+] Total crawled URLs: 10
# Intermediate execution 149 in 2.1408510208129883 seconds
# URL: 149
# [+] Total Internal links: 44
# [+] Total External links: 4
# [+] Total URLs: 48
# [+] Total crawled URLs: 10
# Intermediate execution 150 in 4.804750204086304 seconds
# URL: 150
# [+] Total Internal links: 11
# [+] Total External links: 4
# [+] Total URLs: 15
# [+] Total crawled URLs: 10
# Intermediate execution 151 in 8.359665870666504 seconds
# URL: 151
# [+] Total Internal links: 1
# [+] Total External links: 22
# [+] Total URLs: 23
# [+] Total crawled URLs: 10
# Intermediate execution 152 in 3.035470485687256 seconds
# URL: 152
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 153 in 2.1343202590942383 seconds
# URL: 153
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 154 in 0.2849769592285156 seconds
# URL: 154
# [+] Total Internal links: 0
# [+] Total External links: 5
# [+] Total URLs: 5
# [+] Total crawled URLs: 10
# Intermediate execution 155 in 3.222478151321411 seconds
# URL: 155
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 156 in 0.9354376792907715 seconds
# URL: 156
# [+] Total Internal links: 18
# [+] Total External links: 27
# [+] Total URLs: 45
# [+] Total crawled URLs: 10
# Intermediate execution 157 in 5.040620803833008 seconds
# URL: 157
# [+] Total Internal links: 2
# [+] Total External links: 20
# [+] Total URLs: 22
# [+] Total crawled URLs: 10
# Intermediate execution 158 in 5.371476888656616 seconds
# URL: 158
# [+] Total Internal links: 1
# [+] Total External links: 30
# [+] Total URLs: 31
# [+] Total crawled URLs: 10
# Intermediate execution 159 in 3.863405466079712 seconds
# URL: 159
# [+] Total Internal links: 22
# [+] Total External links: 6
# [+] Total URLs: 28
# [+] Total crawled URLs: 10
# Intermediate execution 160 in 2.369786262512207 seconds
# URL: 160
# [+] Total Internal links: 6
# [+] Total External links: 2
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 161 in 2.598087787628174 seconds
# URL: 161
# [+] Total Internal links: 0
# [+] Total External links: 3
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 162 in 0.9997844696044922 seconds
# URL: 162
# [+] Total Internal links: 6
# [+] Total External links: 5
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 163 in 1.24049973487854 seconds
# URL: 163
# [+] Total Internal links: 12
# [+] Total External links: 3
# [+] Total URLs: 15
# [+] Total crawled URLs: 10
# Intermediate execution 164 in 0.9344649314880371 seconds
# URL: 164
# Not a valid URL
#
# URL: 165
# [+] Total Internal links: 54
# [+] Total External links: 0
# [+] Total URLs: 54
# [+] Total crawled URLs: 10
# Intermediate execution 166 in 1.480161190032959 seconds
# URL: 166
# [+] Total Internal links: 50
# [+] Total External links: 21
# [+] Total URLs: 71
# [+] Total crawled URLs: 10
# Intermediate execution 167 in 1.398479700088501 seconds
# URL: 167
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 168 in 0.9716873168945312 seconds
# URL: 168
# [+] Total Internal links: 3
# [+] Total External links: 106
# [+] Total URLs: 109
# [+] Total crawled URLs: 10
# Intermediate execution 169 in 4.342348575592041 seconds
# URL: 169
# [+] Total Internal links: 311
# [+] Total External links: 6
# [+] Total URLs: 317
# [+] Total crawled URLs: 10
# Intermediate execution 170 in 0.668567419052124 seconds
# URL: 170
# [+] Total Internal links: 18
# [+] Total External links: 5
# [+] Total URLs: 23
# [+] Total crawled URLs: 10
# Intermediate execution 171 in 3.7271909713745117 seconds
# URL: 171
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 172 in 3.0091795921325684 seconds
# URL: 172
# [+] Total Internal links: 16
# [+] Total External links: 1
# [+] Total URLs: 17
# [+] Total crawled URLs: 10
# Intermediate execution 173 in 1.270462989807129 seconds
# URL: 173
# [+] Total Internal links: 37
# [+] Total External links: 10
# [+] Total URLs: 47
# [+] Total crawled URLs: 10
# Intermediate execution 174 in 3.334132671356201 seconds
# URL: 174
# [+] Total Internal links: 3
# [+] Total External links: 3
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 175 in 0.7361938953399658 seconds
# URL: 175
# Not a valid URL
#
# URL: 176
# [+] Total Internal links: 19
# [+] Total External links: 2
# [+] Total URLs: 21
# [+] Total crawled URLs: 10
# Intermediate execution 177 in 1.837660312652588 seconds
# URL: 177
# [+] Total Internal links: 13
# [+] Total External links: 36
# [+] Total URLs: 49
# [+] Total crawled URLs: 10
# Intermediate execution 178 in 3.5575132369995117 seconds
# URL: 178
# [+] Total Internal links: 14
# [+] Total External links: 115
# [+] Total URLs: 129
# [+] Total crawled URLs: 10
# Intermediate execution 179 in 2.1694107055664062 seconds
# URL: 179
# [+] Total Internal links: 73
# [+] Total External links: 6
# [+] Total URLs: 79
# [+] Total crawled URLs: 10
# Intermediate execution 180 in 2.1424617767333984 seconds
# URL: 180
# [+] Total Internal links: 63
# [+] Total External links: 2
# [+] Total URLs: 65
# [+] Total crawled URLs: 10
# Intermediate execution 181 in 1.4688472747802734 seconds
# URL: 181
# [+] Total Internal links: 22
# [+] Total External links: 32
# [+] Total URLs: 54
# [+] Total crawled URLs: 10
# Intermediate execution 182 in 3.2685248851776123 seconds
# URL: 182
# [+] Total Internal links: 26
# [+] Total External links: 4
# [+] Total URLs: 30
# [+] Total crawled URLs: 10
# Intermediate execution 183 in 2.5880484580993652 seconds
# URL: 183
# [+] Total Internal links: 82
# [+] Total External links: 6
# [+] Total URLs: 88
# [+] Total crawled URLs: 10
# Intermediate execution 184 in 2.859837770462036 seconds
# URL: 184
# [+] Total Internal links: 4
# [+] Total External links: 3
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 185 in 2.2863221168518066 seconds
# URL: 185
# Not a valid URL
#
# URL: 186
# [+] Total Internal links: 8
# [+] Total External links: 6
# [+] Total URLs: 14
# [+] Total crawled URLs: 10
# Intermediate execution 187 in 1.2990126609802246 seconds
# URL: 187
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 188 in 2.094841480255127 seconds
# URL: 188
# [+] Total Internal links: 1
# [+] Total External links: 107
# [+] Total URLs: 108
# [+] Total crawled URLs: 10
# Intermediate execution 189 in 3.2880613803863525 seconds
# URL: 189
# [+] Total Internal links: 17
# [+] Total External links: 6
# [+] Total URLs: 23
# [+] Total crawled URLs: 10
# Intermediate execution 190 in 1.7428803443908691 seconds
# URL: 190
# [+] Total Internal links: 19
# [+] Total External links: 3
# [+] Total URLs: 22
# [+] Total crawled URLs: 10
# Intermediate execution 191 in 7.336864709854126 seconds
# URL: 191
# [+] Total Internal links: 6
# [+] Total External links: 31
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 192 in 1.4152956008911133 seconds
# URL: 192
# [+] Total Internal links: 4
# [+] Total External links: 4
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 193 in 0.6411905288696289 seconds
# URL: 193
# Not a valid URL
#
# URL: 194
# [+] Total Internal links: 125
# [+] Total External links: 4
# [+] Total URLs: 129
# [+] Total crawled URLs: 10
# Intermediate execution 195 in 2.672954797744751 seconds
# URL: 195
# [+] Total Internal links: 1
# [+] Total External links: 63
# [+] Total URLs: 64
# [+] Total crawled URLs: 10
# Intermediate execution 196 in 4.638713836669922 seconds
# URL: 196
# [+] Total Internal links: 52
# [+] Total External links: 8
# [+] Total URLs: 60
# [+] Total crawled URLs: 10
# Intermediate execution 197 in 3.220310926437378 seconds
# URL: 197
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 198 in 0.4118170738220215 seconds
# URL: 198
# [+] Total Internal links: 0
# [+] Total External links: 2
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 199 in 5.6292564868927 seconds
# URL: 199
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 200 in 0.60723876953125 seconds
# URL: 200
# [+] Total Internal links: 32
# [+] Total External links: 5
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 201 in 1.4831738471984863 seconds
# URL: 201
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 202 in 1.0156912803649902 seconds
# URL: 202
# [+] Total Internal links: 33
# [+] Total External links: 5
# [+] Total URLs: 38
# [+] Total crawled URLs: 10
# Intermediate execution 203 in 11.158439636230469 seconds
# URL: 203
# Not a valid URL
#
# URL: 204
# [+] Total Internal links: 14
# [+] Total External links: 8
# [+] Total URLs: 22
# [+] Total crawled URLs: 10
# Intermediate execution 205 in 0.604870080947876 seconds
# URL: 205
# [+] Total Internal links: 51
# [+] Total External links: 20
# [+] Total URLs: 71
# [+] Total crawled URLs: 10
# Intermediate execution 206 in 1.6902544498443604 seconds
# URL: 206
# [+] Total Internal links: 36
# [+] Total External links: 6
# [+] Total URLs: 42
# [+] Total crawled URLs: 10
# Intermediate execution 207 in 1.4835691452026367 seconds
# URL: 207
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 208 in 0.26865196228027344 seconds
# URL: 208
# Not a valid URL
#
# URL: 209
# [+] Total Internal links: 6
# [+] Total External links: 31
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 210 in 1.1869533061981201 seconds
# URL: 210
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 211 in 1.2122843265533447 seconds
# URL: 211
# Not a valid URL
#
# URL: 212
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 213 in 1.2285635471343994 seconds
# URL: 213
# [+] Total Internal links: 6
# [+] Total External links: 3
# [+] Total URLs: 9
# [+] Total crawled URLs: 10
# Intermediate execution 214 in 2.0166046619415283 seconds
# URL: 214
# [+] Total Internal links: 51
# [+] Total External links: 8
# [+] Total URLs: 59
# [+] Total crawled URLs: 10
# Intermediate execution 215 in 2.7452468872070312 seconds
# URL: 215
# [+] Total Internal links: 36
# [+] Total External links: 8
# [+] Total URLs: 44
# [+] Total crawled URLs: 10
# Intermediate execution 216 in 3.26206636428833 seconds
# URL: 216
# [+] Total Internal links: 0
# [+] Total External links: 2
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 217 in 0.2508125305175781 seconds
# URL: 217
# [+] Total Internal links: 10
# [+] Total External links: 29
# [+] Total URLs: 39
# [+] Total crawled URLs: 10
# Intermediate execution 218 in 3.390197515487671 seconds
# URL: 218
# [+] Total Internal links: 0
# [+] Total External links: 7
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 219 in 1.2253031730651855 seconds
# URL: 219
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 220 in 1.9795706272125244 seconds
# URL: 220
# [+] Total Internal links: 11
# [+] Total External links: 6
# [+] Total URLs: 17
# [+] Total crawled URLs: 10
# Intermediate execution 221 in 2.4548962116241455 seconds
# URL: 221
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 222 in 2.1482667922973633 seconds
# URL: 222
# [+] Total Internal links: 22
# [+] Total External links: 4
# [+] Total URLs: 26
# [+] Total crawled URLs: 10
# Intermediate execution 223 in 2.305436134338379 seconds
# URL: 223
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 224 in 1.1090266704559326 seconds
# URL: 224
# [+] Total Internal links: 2
# [+] Total External links: 2
# [+] Total URLs: 4
# [+] Total crawled URLs: 10
# Intermediate execution 225 in 1.955245018005371 seconds
# URL: 225
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 226 in 0.897590160369873 seconds
# URL: 226
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 227 in 2.1119093894958496 seconds
# URL: 227
# [+] Total Internal links: 3
# [+] Total External links: 111
# [+] Total URLs: 114
# [+] Total crawled URLs: 10
# Intermediate execution 228 in 2.021775960922241 seconds
# URL: 228
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 229 in 0.5014486312866211 seconds
# URL: 229
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 230 in 1.063913106918335 seconds
# URL: 230
# [+] Total Internal links: 9
# [+] Total External links: 12
# [+] Total URLs: 21
# [+] Total crawled URLs: 10
# Intermediate execution 231 in 1.6254420280456543 seconds
# URL: 231
# [+] Total Internal links: 69
# [+] Total External links: 5
# [+] Total URLs: 74
# [+] Total crawled URLs: 10
# Intermediate execution 232 in 3.220608949661255 seconds
# URL: 232
# Not a valid URL
#
# URL: 233
# [+] Total Internal links: 4
# [+] Total External links: 2
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 234 in 1.5606958866119385 seconds
# URL: 234
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 235 in 1.424189805984497 seconds
# URL: 235
# Not a valid URL
#
# URL: 236
# [+] Total Internal links: 97
# [+] Total External links: 23
# [+] Total URLs: 120
# [+] Total crawled URLs: 10
# Intermediate execution 237 in 0.7626912593841553 seconds
# URL: 237
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 238 in 1.7639436721801758 seconds
# URL: 238
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 239 in 0.933983564376831 seconds
# URL: 239
# Not a valid URL
#
# URL: 240
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 241 in 0.6886725425720215 seconds
# URL: 241
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 242 in 1.0574405193328857 seconds
# URL: 242
# [+] Total Internal links: 6
# [+] Total External links: 1
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 243 in 0.7119913101196289 seconds
# URL: 243
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 244 in 0.9053301811218262 seconds
# URL: 244
# [+] Total Internal links: 18
# [+] Total External links: 7
# [+] Total URLs: 25
# [+] Total crawled URLs: 10
# Intermediate execution 245 in 2.522887945175171 seconds
# URL: 245
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 246 in 0.9322102069854736 seconds
# URL: 246
# [+] Total Internal links: 2
# [+] Total External links: 0
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 247 in 1.724247694015503 seconds
# URL: 247
# [+] Total Internal links: 14
# [+] Total External links: 12
# [+] Total URLs: 26
# [+] Total crawled URLs: 10
# Intermediate execution 248 in 2.069525957107544 seconds
# URL: 248
# [+] Total Internal links: 1
# [+] Total External links: 5
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 249 in 1.7457373142242432 seconds
# URL: 249
# [+] Total Internal links: 7
# [+] Total External links: 1
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 250 in 3.137007236480713 seconds
# URL: 250
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 251 in 1.562697410583496 seconds
# URL: 251
# [+] Total Internal links: 18
# [+] Total External links: 1
# [+] Total URLs: 19
# [+] Total crawled URLs: 10
# Intermediate execution 252 in 1.2478361129760742 seconds
# URL: 252
# [+] Total Internal links: 94
# [+] Total External links: 23
# [+] Total URLs: 117
# [+] Total crawled URLs: 10
# Intermediate execution 253 in 11.259391784667969 seconds
# URL: 253
# [+] Total Internal links: 27
# [+] Total External links: 5
# [+] Total URLs: 32
# [+] Total crawled URLs: 10
# Intermediate execution 254 in 2.7307145595550537 seconds
# URL: 254
# [+] Total Internal links: 31
# [+] Total External links: 10
# [+] Total URLs: 41
# [+] Total crawled URLs: 10
# Intermediate execution 255 in 11.911890506744385 seconds
# URL: 255
# Not a valid URL
#
# URL: 256
# [+] Total Internal links: 11
# [+] Total External links: 40
# [+] Total URLs: 51
# [+] Total crawled URLs: 10
# Intermediate execution 257 in 11.626835823059082 seconds
# URL: 257
# [+] Total Internal links: 20
# [+] Total External links: 7
# [+] Total URLs: 27
# [+] Total crawled URLs: 10
# Intermediate execution 258 in 0.6043083667755127 seconds
# URL: 258
# [+] Total Internal links: 16
# [+] Total External links: 3
# [+] Total URLs: 19
# [+] Total crawled URLs: 10
# Intermediate execution 259 in 1.2601206302642822 seconds
# URL: 259
# Not a valid URL
#
# URL: 260
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 261 in 0.7842807769775391 seconds
# URL: 261
# [+] Total Internal links: 45
# [+] Total External links: 9
# [+] Total URLs: 54
# [+] Total crawled URLs: 10
# Intermediate execution 262 in 2.4951364994049072 seconds
# URL: 262
# [+] Total Internal links: 0
# [+] Total External links: 11
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 263 in 0.6869351863861084 seconds
# URL: 263
# [+] Total Internal links: 12
# [+] Total External links: 5
# [+] Total URLs: 17
# [+] Total crawled URLs: 10
# Intermediate execution 264 in 4.364279508590698 seconds
# URL: 264
# Not a valid URL
#
# URL: 265
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 266 in 1.506655216217041 seconds
# URL: 266
# [+] Total Internal links: 0
# [+] Total External links: 3
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 267 in 0.9529964923858643 seconds
# URL: 267
# [+] Total Internal links: 4
# [+] Total External links: 27
# [+] Total URLs: 31
# [+] Total crawled URLs: 10
# Intermediate execution 268 in 1.1968152523040771 seconds
# URL: 268
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 269 in 0.43659448623657227 seconds
# URL: 269
# Not a valid URL
#
# URL: 270
# [+] Total Internal links: 3
# [+] Total External links: 4
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 271 in 0.8159453868865967 seconds
# URL: 271
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 272 in 2.214982748031616 seconds
# URL: 272
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 273 in 0.6721923351287842 seconds
# URL: 273
# [+] Total Internal links: 1
# [+] Total External links: 32
# [+] Total URLs: 33
# [+] Total crawled URLs: 10
# Intermediate execution 274 in 4.586917400360107 seconds
# URL: 274
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 275 in 0.7518792152404785 seconds
# URL: 275
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 276 in 1.074134349822998 seconds
# URL: 276
# [+] Total Internal links: 133
# [+] Total External links: 0
# [+] Total URLs: 133
# [+] Total crawled URLs: 10
# Intermediate execution 277 in 1.3146724700927734 seconds
# URL: 277
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 278 in 0.8242568969726562 seconds
# URL: 278
# Not a valid URL
#
# URL: 279
# [+] Total Internal links: 59
# [+] Total External links: 10
# [+] Total URLs: 69
# [+] Total crawled URLs: 10
# Intermediate execution 280 in 3.448881149291992 seconds
# URL: 280
# [+] Total Internal links: 44
# [+] Total External links: 2
# [+] Total URLs: 46
# [+] Total crawled URLs: 10
# Intermediate execution 281 in 1.5832645893096924 seconds
# URL: 281
# [+] Total Internal links: 46
# [+] Total External links: 22
# [+] Total URLs: 68
# [+] Total crawled URLs: 10
# Intermediate execution 282 in 1.019399881362915 seconds
# URL: 282
# Not a valid URL
#
# URL: 283
# [+] Total Internal links: 2
# [+] Total External links: 13
# [+] Total URLs: 15
# [+] Total crawled URLs: 10
# Intermediate execution 284 in 1.5223851203918457 seconds
# URL: 284
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 285 in 1.3234763145446777 seconds
# URL: 285
# [+] Total Internal links: 15
# [+] Total External links: 13
# [+] Total URLs: 28
# [+] Total crawled URLs: 10
# Intermediate execution 286 in 2.7696099281311035 seconds
# URL: 286
# [+] Total Internal links: 1
# [+] Total External links: 42
# [+] Total URLs: 43
# [+] Total crawled URLs: 10
# Intermediate execution 287 in 4.49533748626709 seconds
# URL: 287
# [+] Total Internal links: 30
# [+] Total External links: 0
# [+] Total URLs: 30
# [+] Total crawled URLs: 10
# Intermediate execution 288 in 2.9136791229248047 seconds
# URL: 288
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 289 in 1.1387245655059814 seconds
# URL: 289
# [+] Total Internal links: 531
# [+] Total External links: 107
# [+] Total URLs: 638
# [+] Total crawled URLs: 10
# Intermediate execution 290 in 0.7279644012451172 seconds
# URL: 290
# [+] Total Internal links: 1
# [+] Total External links: 7
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 291 in 2.668384075164795 seconds
# URL: 291
# [+] Total Internal links: 161
# [+] Total External links: 23
# [+] Total URLs: 184
# [+] Total crawled URLs: 10
# Intermediate execution 292 in 2.877084255218506 seconds
# URL: 292
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 293 in 1.0764880180358887 seconds
# URL: 293
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 294 in 0.9239239692687988 seconds
# URL: 294
# [+] Total Internal links: 23
# [+] Total External links: 9
# [+] Total URLs: 32
# [+] Total crawled URLs: 10
# Intermediate execution 295 in 1.1982643604278564 seconds
# URL: 295
# [+] Total Internal links: 21
# [+] Total External links: 12
# [+] Total URLs: 33
# [+] Total crawled URLs: 10
# Intermediate execution 296 in 1.8115513324737549 seconds
# URL: 296
# [+] Total Internal links: 1
# [+] Total External links: 11
# [+] Total URLs: 12
# [+] Total crawled URLs: 10
# Intermediate execution 297 in 3.2215840816497803 seconds
# URL: 297
# [+] Total Internal links: 2
# [+] Total External links: 15
# [+] Total URLs: 17
# [+] Total crawled URLs: 10
# Intermediate execution 298 in 1.9501304626464844 seconds
# URL: 298
# [+] Total Internal links: 48
# [+] Total External links: 6
# [+] Total URLs: 54
# [+] Total crawled URLs: 10
# Intermediate execution 299 in 9.205661296844482 seconds
# URL: 299
# [+] Total Internal links: 2
# [+] Total External links: 28
# [+] Total URLs: 30
# [+] Total crawled URLs: 10
# Intermediate execution 300 in 2.145597219467163 seconds
# URL: 300
# [+] Total Internal links: 1
# [+] Total External links: 10
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 301 in 3.707789659500122 seconds
# URL: 301
# [+] Total Internal links: 25
# [+] Total External links: 5
# [+] Total URLs: 30
# [+] Total crawled URLs: 10
# Intermediate execution 302 in 3.0883116722106934 seconds
# URL: 302
# [+] Total Internal links: 19
# [+] Total External links: 6
# [+] Total URLs: 25
# [+] Total crawled URLs: 10
# Intermediate execution 303 in 2.00622296333313 seconds
# URL: 303
# [+] Total Internal links: 9
# [+] Total External links: 1
# [+] Total URLs: 10
# [+] Total crawled URLs: 10
# Intermediate execution 304 in 3.031813144683838 seconds
# URL: 304
# [+] Total Internal links: 63
# [+] Total External links: 3
# [+] Total URLs: 66
# [+] Total crawled URLs: 10
# Intermediate execution 305 in 1.5190482139587402 seconds
# URL: 305
# [+] Total Internal links: 13
# [+] Total External links: 14
# [+] Total URLs: 27
# [+] Total crawled URLs: 10
# Intermediate execution 306 in 2.1383635997772217 seconds
# URL: 306
# Not a valid URL
#
# URL: 307
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 308 in 1.5521535873413086 seconds
# URL: 308
# [+] Total Internal links: 10
# [+] Total External links: 3
# [+] Total URLs: 13
# [+] Total crawled URLs: 10
# Intermediate execution 309 in 1.7917447090148926 seconds
# URL: 309
# [+] Total Internal links: 41
# [+] Total External links: 2
# [+] Total URLs: 43
# [+] Total crawled URLs: 10
# Intermediate execution 310 in 2.3657939434051514 seconds
# URL: 310
# [+] Total Internal links: 2
# [+] Total External links: 5
# [+] Total URLs: 7
# ...
# Intermediate execution 1850 in 1.971212387084961 seconds
# URL: 1850
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1851 in 1.2667076587677002 seconds
# URL: 1851
# [+] Total Internal links: 16
# [+] Total External links: 13
# [+] Total URLs: 29
# [+] Total crawled URLs: 10
# Intermediate execution 1852 in 3.326737642288208 seconds
# URL: 1852
# [+] Total Internal links: 38
# [+] Total External links: 5
# [+] Total URLs: 43
# [+] Total crawled URLs: 10
# Intermediate execution 1853 in 1.4769964218139648 seconds
# URL: 1853
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1854 in 1.2816803455352783 seconds
# URL: 1854
# [+] Total Internal links: 33
# [+] Total External links: 4
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 1855 in 2.019014358520508 seconds
# URL: 1855
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1856 in 1.1174297332763672 seconds
# URL: 1856
# [+] Total Internal links: 21
# [+] Total External links: 4
# [+] Total URLs: 25
# [+] Total crawled URLs: 10
# Intermediate execution 1857 in 3.0102462768554688 seconds
# URL: 1857
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1858 in 1.3884446620941162 seconds
# URL: 1858
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1859 in 1.6838226318359375 seconds
# URL: 1859
# [+] Total Internal links: 75
# [+] Total External links: 19
# [+] Total URLs: 94
# [+] Total crawled URLs: 10
# Intermediate execution 1860 in 3.849938154220581 seconds
# URL: 1860
# [+] Total Internal links: 395
# [+] Total External links: 4
# [+] Total URLs: 399
# [+] Total crawled URLs: 10
# Intermediate execution 1861 in 7.1480817794799805 seconds
# URL: 1861
# [+] Total Internal links: 0
# [+] Total External links: 10
# [+] Total URLs: 10
# [+] Total crawled URLs: 10
# Intermediate execution 1862 in 5.92150616645813 seconds
# URL: 1862
# [+] Total Internal links: 6
# [+] Total External links: 1
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 1863 in 0.7776920795440674 seconds
# URL: 1863
# Not a valid URL
#
# URL: 1864
# [+] Total Internal links: 7
# [+] Total External links: 1
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 1865 in 2.701500415802002 seconds
# URL: 1865
# [+] Total Internal links: 19
# [+] Total External links: 6
# [+] Total URLs: 25
# [+] Total crawled URLs: 10
# Intermediate execution 1866 in 4.008473634719849 seconds
# URL: 1866
# Not a valid URL
#
# URL: 1867
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1868 in 1.321148157119751 seconds
# URL: 1868
# [+] Total Internal links: 11
# [+] Total External links: 1
# [+] Total URLs: 12
# [+] Total crawled URLs: 10
# Intermediate execution 1869 in 2.0201284885406494 seconds
# URL: 1869
# [+] Total Internal links: 52
# [+] Total External links: 18
# [+] Total URLs: 70
# [+] Total crawled URLs: 10
# Intermediate execution 1870 in 2.136262893676758 seconds
# URL: 1870
# [+] Total Internal links: 11
# [+] Total External links: 2
# [+] Total URLs: 13
# [+] Total crawled URLs: 10
# Intermediate execution 1871 in 3.9910728931427 seconds
# URL: 1871
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1872 in 1.3563988208770752 seconds
# URL: 1872
# [+] Total Internal links: 2
# [+] Total External links: 1
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 1873 in 1.0640544891357422 seconds
# URL: 1873
# Not a valid URL
#
# URL: 1874
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1875 in 0.37084436416625977 seconds
# URL: 1875
# [+] Total Internal links: 33
# [+] Total External links: 1
# [+] Total URLs: 34
# [+] Total crawled URLs: 10
# Intermediate execution 1876 in 2.4984755516052246 seconds
# URL: 1876
# Not a valid URL
#
# URL: 1877
# [+] Total Internal links: 50
# [+] Total External links: 10
# [+] Total URLs: 60
# [+] Total crawled URLs: 10
# Intermediate execution 1878 in 1.774226427078247 seconds
# URL: 1878
# [+] Total Internal links: 0
# [+] Total External links: 2
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 1879 in 0.6726508140563965 seconds
# URL: 1879
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1880 in 0.3499112129211426 seconds
# URL: 1880
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1881 in 0.4813425540924072 seconds
# URL: 1881
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1882 in 1.4230263233184814 seconds
# URL: 1882
# [+] Total Internal links: 0
# [+] Total External links: 3
# [+] Total URLs: 3
# [+] Total crawled URLs: 10
# Intermediate execution 1883 in 1.5955140590667725 seconds
# URL: 1883
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1884 in 0.4203603267669678 seconds
# URL: 1884
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1885 in 0.8945109844207764 seconds
# URL: 1885
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1886 in 1.127124309539795 seconds
# URL: 1886
# Not a valid URL
#
# URL: 1887
# [+] Total Internal links: 66
# [+] Total External links: 2
# [+] Total URLs: 68
# [+] Total crawled URLs: 10
# Intermediate execution 1888 in 1.5359413623809814 seconds
# URL: 1888
# [+] Total Internal links: 20
# [+] Total External links: 4
# [+] Total URLs: 24
# [+] Total crawled URLs: 10
# Intermediate execution 1889 in 1.8654117584228516 seconds
# URL: 1889
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1890 in 0.7853615283966064 seconds
# URL: 1890
# Not a valid URL
#
# URL: 1891
# [+] Total Internal links: 0
# [+] Total External links: 129
# [+] Total URLs: 129
# [+] Total crawled URLs: 10
# Intermediate execution 1892 in 3.0829670429229736 seconds
# URL: 1892
# [+] Total Internal links: 14
# [+] Total External links: 86
# [+] Total URLs: 100
# [+] Total crawled URLs: 10
# Intermediate execution 1893 in 4.5027101039886475 seconds
# URL: 1893
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1894 in 0.9256875514984131 seconds
# URL: 1894
# [+] Total Internal links: 43
# [+] Total External links: 7
# [+] Total URLs: 50
# [+] Total crawled URLs: 10
# Intermediate execution 1895 in 1.549800157546997 seconds
# URL: 1895
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1896 in 1.0896213054656982 seconds
# URL: 1896
# [+] Total Internal links: 19
# [+] Total External links: 41
# [+] Total URLs: 60
# [+] Total crawled URLs: 10
# Intermediate execution 1897 in 5.803472280502319 seconds
# URL: 1897
# [+] Total Internal links: 8
# [+] Total External links: 3
# [+] Total URLs: 11
# [+] Total crawled URLs: 10
# Intermediate execution 1898 in 2.2381129264831543 seconds
# URL: 1898
# [+] Total Internal links: 82
# [+] Total External links: 28
# [+] Total URLs: 110
# [+] Total crawled URLs: 10
# Intermediate execution 1899 in 6.5297746658325195 seconds
# URL: 1899
# [+] Total Internal links: 92
# [+] Total External links: 1
# [+] Total URLs: 93
# [+] Total crawled URLs: 10
# Intermediate execution 1900 in 1.9847824573516846 seconds
# URL: 1900
# [+] Total Internal links: 60
# [+] Total External links: 7
# [+] Total URLs: 67
# [+] Total crawled URLs: 10
# Intermediate execution 1901 in 7.419352054595947 seconds
# URL: 1901
# [+] Total Internal links: 20
# [+] Total External links: 74
# [+] Total URLs: 94
# [+] Total crawled URLs: 10
# Intermediate execution 1902 in 6.990706920623779 seconds
# URL: 1902
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1903 in 2.2574174404144287 seconds
# URL: 1903
# [+] Total Internal links: 162
# [+] Total External links: 1
# [+] Total URLs: 163
# [+] Total crawled URLs: 10
# Intermediate execution 1904 in 0.9599282741546631 seconds
# URL: 1904
# [+] Total Internal links: 108
# [+] Total External links: 22
# [+] Total URLs: 130
# [+] Total crawled URLs: 10
# Intermediate execution 1905 in 4.909077405929565 seconds
# URL: 1905
# [+] Total Internal links: 31
# [+] Total External links: 49
# [+] Total URLs: 80
# [+] Total crawled URLs: 10
# Intermediate execution 1906 in 2.806776523590088 seconds
# URL: 1906
# Not a valid URL
#
# URL: 1907
# [+] Total Internal links: 6
# [+] Total External links: 2
# [+] Total URLs: 8
# [+] Total crawled URLs: 10
# Intermediate execution 1908 in 0.6834087371826172 seconds
# URL: 1908
# [+] Total Internal links: 32
# [+] Total External links: 2
# [+] Total URLs: 34
# [+] Total crawled URLs: 10
# Intermediate execution 1909 in 0.509058952331543 seconds
# URL: 1909
# [+] Total Internal links: 19
# [+] Total External links: 3
# [+] Total URLs: 22
# [+] Total crawled URLs: 10
# Intermediate execution 1910 in 2.27854323387146 seconds
# URL: 1910
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1911 in 0.8766777515411377 seconds
# URL: 1911
# [+] Total Internal links: 3
# [+] Total External links: 4
# [+] Total URLs: 7
# [+] Total crawled URLs: 10
# Intermediate execution 1912 in 1.9753198623657227 seconds
# URL: 1912
# [+] Total Internal links: 58
# [+] Total External links: 7
# [+] Total URLs: 65
# [+] Total crawled URLs: 10
# Intermediate execution 1913 in 3.842625379562378 seconds
# URL: 1913
# [+] Total Internal links: 32
# [+] Total External links: 5
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 1914 in 2.2313902378082275 seconds
# URL: 1914
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1915 in 1.3665590286254883 seconds
# URL: 1915
# [+] Total Internal links: 35
# [+] Total External links: 12
# [+] Total URLs: 47
# [+] Total crawled URLs: 10
# Intermediate execution 1916 in 3.5698490142822266 seconds
# URL: 1916
# [+] Total Internal links: 4
# [+] Total External links: 0
# [+] Total URLs: 4
# [+] Total crawled URLs: 10
# Intermediate execution 1917 in 1.7895221710205078 seconds
# URL: 1917
# [+] Total Internal links: 1
# [+] Total External links: 1
# [+] Total URLs: 2
# [+] Total crawled URLs: 10
# Intermediate execution 1918 in 0.22309255599975586 seconds
# URL: 1918
# [+] Total Internal links: 2
# [+] Total External links: 1472
# [+] Total URLs: 1474
# [+] Total crawled URLs: 10
# Intermediate execution 1919 in 2.455418109893799 seconds
# URL: 1919
# [+] Total Internal links: 2
# [+] Total External links: 15
# [+] Total URLs: 17
# [+] Total crawled URLs: 10
# Intermediate execution 1920 in 4.054189443588257 seconds
# URL: 1920
# Not a valid URL
#
# URL: 1921
# [+] Total Internal links: 7
# [+] Total External links: 8
# [+] Total URLs: 15
# [+] Total crawled URLs: 10
# Intermediate execution 1922 in 5.305605173110962 seconds
# URL: 1922
# [+] Total Internal links: 15
# [+] Total External links: 6
# [+] Total URLs: 21
# [+] Total crawled URLs: 10
# Intermediate execution 1923 in 1.2737650871276855 seconds
# URL: 1923
# [+] Total Internal links: 17
# [+] Total External links: 2
# [+] Total URLs: 19
# [+] Total crawled URLs: 10
# Intermediate execution 1924 in 0.7768599987030029 seconds
# URL: 1924
# [+] Total Internal links: 10
# [+] Total External links: 241
# [+] Total URLs: 251
# [+] Total crawled URLs: 10
# Intermediate execution 1925 in 5.644989728927612 seconds
# URL: 1925
# [+] Total Internal links: 32
# [+] Total External links: 5
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 1926 in 0.6952624320983887 seconds
# URL: 1926
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1927 in 1.2741937637329102 seconds
# URL: 1927
# [+] Total Internal links: 1
# [+] Total External links: 15
# [+] Total URLs: 16
# [+] Total crawled URLs: 10
# Intermediate execution 1928 in 4.316373825073242 seconds
# URL: 1928
# [+] Total Internal links: 11
# [+] Total External links: 5
# [+] Total URLs: 16
# [+] Total crawled URLs: 10
# Intermediate execution 1929 in 1.5164391994476318 seconds
# URL: 1929
# [+] Total Internal links: 40
# [+] Total External links: 14
# [+] Total URLs: 54
# [+] Total crawled URLs: 10
# Intermediate execution 1930 in 1.8785336017608643 seconds
# URL: 1930
# Not a valid URL
#
# URL: 1931
# [+] Total Internal links: 1
# [+] Total External links: 45
# [+] Total URLs: 46
# [+] Total crawled URLs: 10
# Intermediate execution 1932 in 3.2488532066345215 seconds
# URL: 1932
# [+] Total Internal links: 6
# [+] Total External links: 0
# [+] Total URLs: 6
# [+] Total crawled URLs: 10
# Intermediate execution 1933 in 1.7900052070617676 seconds
# URL: 1933
# [+] Total Internal links: 60
# [+] Total External links: 2
# [+] Total URLs: 62
# [+] Total crawled URLs: 10
# Intermediate execution 1934 in 1.418928861618042 seconds
# URL: 1934
# [+] Total Internal links: 1
# [+] Total External links: 28
# [+] Total URLs: 29
# [+] Total crawled URLs: 10
# Intermediate execution 1935 in 0.6868314743041992 seconds
# URL: 1935
# [+] Total Internal links: 46
# [+] Total External links: 49
# [+] Total URLs: 95
# [+] Total crawled URLs: 10
# Intermediate execution 1936 in 1.853389024734497 seconds
# URL: 1936
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1937 in 1.0535085201263428 seconds
# URL: 1937
# [+] Total Internal links: 0
# [+] Total External links: 1
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1938 in 1.53242826461792 seconds
# URL: 1938
# [+] Total Internal links: 13
# [+] Total External links: 15
# [+] Total URLs: 28
# [+] Total crawled URLs: 10
# Intermediate execution 1939 in 3.834768772125244 seconds
# URL: 1939
# [+] Total Internal links: 9
# [+] Total External links: 14
# [+] Total URLs: 23
# [+] Total crawled URLs: 10
# Intermediate execution 1940 in 1.976273536682129 seconds
# URL: 1940
# [+] Total Internal links: 6
# [+] Total External links: 31
# [+] Total URLs: 37
# [+] Total crawled URLs: 10
# Intermediate execution 1941 in 2.4981589317321777 seconds
# URL: 1941
# [+] Total Internal links: 6
# [+] Total External links: 6
# [+] Total URLs: 12
# [+] Total crawled URLs: 10
# Intermediate execution 1942 in 1.2028722763061523 seconds
# URL: 1942
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1943 in 0.777733325958252 seconds
# URL: 1943
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1944 in 1.4093406200408936 seconds
# URL: 1944
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1945 in 1.1579196453094482 seconds
# URL: 1945
# [+] Total Internal links: 14
# [+] Total External links: 0
# [+] Total URLs: 14
# [+] Total crawled URLs: 10
# Intermediate execution 1946 in 1.8714172840118408 seconds
# URL: 1946
# [+] Total Internal links: 1
# [+] Total External links: 0
# [+] Total URLs: 1
# [+] Total crawled URLs: 10
# Intermediate execution 1947 in 0.6272380352020264 seconds
# URL: 1947
# [+] Total Internal links: 34
# [+] Total External links: 11
# [+] Total URLs: 45
# [+] Total crawled URLs: 10
# Intermediate execution 1948 in 1.3737657070159912 seconds
# URL: 1948
# [+] Total Internal links: 0
# [+] Total External links: 0
# [+] Total URLs: 0
# [+] Total crawled URLs: 10
# Intermediate execution 1949 in 1.544569730758667 seconds
# URL: 1949
# [+] Total Internal links: 0
# [+] Total External links: 5
# [+] Total URLs: 5
# [+] Total crawled URLs: 10
# Intermediate execution 1950 in 1.4684011936187744 seconds
# URL: 1950
# [+] Total Internal links: 5
# [+] Total External links: 22
# [+] Total URLs: 27
# [+] Total crawled URLs: 10
# Intermediate execution 1951 in 2.5074961185455322 seconds
# Finished execution in: 42945.823227882385 seconds

# %%
len(final_internal)
# Out:
# 1950

# %%
len(final_external)
# Out:
# 1950

# %%
df = Sample1
df['Internal_links'] = final_internal
df['External_links'] = final_external
result = [0] * len(df)
df['Result'] = result
df
# Out:
#       Unnamed: 0                                                URL  \
# 0              0   http://www.lf1.cuni.cz/default.asp?nLanguageID=2
# 1              1                     http://www.thecustomcards.com/
# 2              2                       http://tillamook.cpcbsa.org/
# 3              3                           http://www.mpaskina.com/
# 4              4       http://www.wiltsgames.co.uk/highsociety.html
# ...          ...                                                ...
# 1945        1945               http://kimscraftbooks.homestead.com/
# 1946        1946                         http://www.futurecity.org/
# 1947        1947                          http://www.stillruns.com/
# 1948        1948  http://members.tripod.com/~louis_armand/index....
# 1949        1949                         http://www.dawdyphoto.com/
#
#                                                   whois             creation  \
# 0     ('cuni.cz', datetime.datetime(1996, 10, 3, 1, ...  1996-10-03 01:00:00
# 1     ('THECUSTOMCARDS.COM', datetime.datetime(2021,...  2021-01-24 19:12:39
# 2     (['CPCBSA.ORG', 'cpcbsa.org'], [datetime.datet...  1996-10-22 04:00:00
# 3     (['MPASKINA.COM', 'mpaskina.com'], [datetime.d...  2009-01-10 20:01:05
# 4     ('wiltsgames.co.uk', datetime.datetime(2020, 8...  2020-08-06 00:00:00
# ...                                                 ...                  ...
# 1945  ('HOMESTEAD.COM', datetime.datetime(1997, 6, 2...  1997-06-21 04:00:00
# 1946  ('FUTURECITY.ORG', datetime.datetime(1998, 5, ...  1998-05-07 04:00:00
# 1947  ('STILLRUNS.COM', datetime.datetime(2002, 1, 1...  2002-01-13 04:38:11
# 1948  (['TRIPOD.COM', 'tripod.com'], [datetime.datet...  1994-09-29 04:00:00
# 1949  ('DAWDYPHOTO.COM', datetime.datetime(1999, 4, ...  1999-04-05 04:00:00
#
#                expiration             duration  Internal_links  \
# 0     2025-10-10 00:00:00  10598 days 23:00:00             123
# 1     2022-01-24 19:12:39    365 days 00:00:00               0
# 2     2021-10-21 04:00:00   9130 days 00:00:00               0
# 3     2022-01-10 20:01:05   4748 days 00:00:00              35
# 4     2021-08-06 00:00:00    365 days 00:00:00               0
# ...                   ...                  ...             ...
# 1945  2026-06-20 04:00:00  10591 days 00:00:00               1
# 1946  2022-05-06 04:00:00   8765 days 00:00:00              34
# 1947  2022-01-13 04:38:11   7305 days 00:00:00               0
# 1948  2021-09-28 04:00:00   9861 days 00:00:00               0
# 1949  2025-04-05 04:00:00   9497 days 00:00:00               5
#
#       External_links  Result
# 0                108       0
# 1                  0       0
# 2                  0       0
# 3                  2       0
# 4                  2       0
# ...              ...     ...
# 1945               0       0
# 1946              11       0
# 1947               0       0
# 1948               5       0
# 1949              22       0
#
# [1950 rows x 9 columns]

# %%
df.to_csv('Whois_intext.csv')
